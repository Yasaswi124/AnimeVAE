# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import os
images = []

# %%
len(os.listdir('cats/cats'))
# Out:
# 15747

# %%
for i in tqdm(os.listdir('cats/cats')):
    im = plt.imread('cats/cats/' + i)
    images.append(im)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=15747.0), HTML(value='')))

# %%
len(images)
# Out:
# 15747

# %%
plt.imshow(images[100])

# %%
plt.imshow(images[1000])

# %%
images = np.array(images)

# %%
images.shape
# Out:
# (15747, 64, 64, 3)

# %%
images.max()
# Out:
# 255

# %%
images.min()
# Out:
# 0

# %%
images = (images)/images.max()

# %%
images.max()
# Out:
# 1.0

# %%
type(images[0][0][0][0])
# Out:
# numpy.float64

# %%
images = np.float32(images)

# %%
type(images[0][0][0][0])
# Out:
# numpy.float32

# %%
plt.imshow(images[100])

# %%
plt.imshow(images[1000])

# %%
images.shape
# Out:
# (15747, 64, 64, 3)

# %%
np.save('cats_images.npy', images)
